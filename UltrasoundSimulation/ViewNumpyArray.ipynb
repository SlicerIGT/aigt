# %%
import matplotlib.pyplot as plt
import numpy as np
image_folder = r"C:\Data\Temp"

# %%
segmentation_np = np.load(image_folder + r"\NeedleCapture_01_0310_segmentation.npy")
ultrasound_np = np.load(image_folder + r"\NeedleCapture_01_0310_ultrasound.npy")

# %%
#check size
segsize = segmentation_np.shape[0]
print(segmentation_np.shape)
print(ultrasound_np.shape)
# Out:
# (5, 512, 512)
# (1, 512, 512)

# %%
plt.imshow(ultrasound_np[0])

# %%
fig = plt.figure(figsize=(13, segsize*5))
for i in range(0,segsize):
    a = fig.add_subplot(segsize,3,i*3+1)
    imgplot = plt.imshow(segmentation_np[i])
