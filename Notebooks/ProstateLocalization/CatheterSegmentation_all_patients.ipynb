# %%
from DICOMLib import DICOMUtils
import vtkSegmentationCorePython as vtkSegmentationCore
import numpy


# Code from https://github.com/SlicerRt/SlicerRT/blob/master/BatchProcessing/BatchStructureSetConversion.py
def ConvertStructureSetToLabelmap():
    # ConvertStructureSetToLabelmap()
    labelmapsToSave = []

    # Get all segmentation nodes from the scene
    segmentationNodes = slicer.util.getNodes('vtkMRMLSegmentationNode*')

    for segmentationNode in segmentationNodes.values():
        # Set referenced volume as rasterization reference
        referenceVolume = slicer.vtkSlicerDicomRtImportExportModuleLogic.GetReferencedVolumeByDicomForSegmentation(
            segmentationNode)
        if referenceVolume == None:
            continue

    # Perform conversion
    binaryLabelmapRepresentationName = vtkSegmentationCore.vtkSegmentationConverter.GetSegmentationBinaryLabelmapRepresentationName()
    segmentation = segmentationNode.GetSegmentation()
    segmentation.CreateRepresentation(binaryLabelmapRepresentationName)

    # Create labelmap volume nodes from binary labelmaps
    segmentIDs = vtk.vtkStringArray()
    segmentation.GetSegmentIDs(segmentIDs)
    for segmentIndex in range(0, segmentIDs.GetNumberOfValues()):
        segmentID = segmentIDs.GetValue(segmentIndex)
        segment = segmentation.GetSegment(segmentID)
        binaryLabelmap = segment.GetRepresentation(
            vtkSegmentationCore.vtkSegmentationConverter.GetSegmentationBinaryLabelmapRepresentationName())
        if not binaryLabelmap:
            continue
        labelmapNode = slicer.vtkMRMLLabelMapVolumeNode()
        slicer.mrmlScene.AddNode(labelmapNode)
        labelmapName = segmentationNode.GetName() + "_" + segmentID
        labelmapNode.SetName(labelmapName)
        if not slicer.vtkSlicerSegmentationsModuleLogic.CreateLabelmapVolumeFromOrientedImageData(
          binaryLabelmap, labelmapNode):
            continue

        # Append volume to list
        labelmapsToSave.append(labelmapNode)# SaveLabelmaps into output_dir

    return labelmapsToSave


def SaveLabelmaps(labelmapsToSave, outputDir):
    for labelmapNode in labelmapsToSave:
        # Clean up file name and set path
        fileName = labelmapNode.GetName() + '.nrrd'
        table = str.maketrans(dict.fromkeys('!?:;'))
        fileName = fileName.translate(table)
        filePath = outputDir + '/' + fileName
        logging.info('  Saving structure ' + labelmapNode.GetName() + '\n    to file ' + fileName)

    # Save to file
    success = slicer.util.saveNode(labelmapNode, filePath)
    if not success:
        logging.error('Failed to save labelmap: ' + filePath)


# Exporting data from all testing/training brachytherapy patients
folder_prefix = 'downloads/Brachy patients/PYPB'


for patient_num in range(1, 31):
    # Clear scene
    slicer.mrmlScene.Clear(False)

    #concatenate folder name
    folder_name = folder_prefix + str(patient_num).zfill(2)
    
    # Load dicom folder
    DICOMUtils.openTemporaryDatabase()
    DICOMUtils.importDicom(folder_name)

    #Load first patient into slicer
    patient = slicer.dicomDatabase.patients()[0]
    DICOMUtils.loadPatientByUID(patient)

    output_dir = slicer.app.temporaryPath + '/BrachyPatients/Output/' + str(patient_num).zfill(2)
    labelmaps = ConvertStructureSetToLabelmap()
    SaveLabelmaps(labelmaps, output_dir)
    
    # Get first plan node
    planNodes = slicer.util.getNodes('vtkMRMLRTPlanNode*')
    planNode = list(planNodes.values())[0]
    # Get ultrasound volume node
    ultrasoundNodes = slicer.util.getNodes('vtkMRMLScalarVolumeNode*')
    ultrasoundNode = list(ultrasoundNodes.values())[0]

    
    # Get catheter nodes (children of plan in SH)
    shNode = slicer.vtkMRMLSubjectHierarchyNode.GetSubjectHierarchyNode(slicer.mrmlScene)
    planItemID = shNode.GetItemByDataNode(planNode)
    children = vtk.vtkIdList()
    shNode.GetItemChildren(planItemID, children)

    catheterNodes = []
    for i in range(children.GetNumberOfIds()):
        child = children.GetId(i)
        catheterNode = shNode.GetItemDataNode(child)
        catheterNodes.append(catheterNode)

    # Convert each catheter node into labelmap nodes
    modelNodes = []
    for catheterNode in catheterNodes:
        # 1. Get model from catheter markups curve
        catheterNode.SetCurveTypeToLinear()
        polydata = catheterNode.GetCurveWorld()
        # add catheter diameter
        polydataTube = vtk.vtkTubeFilter()
        polydataTube.SetInputData(polydata)
        polydataTube.SetNumberOfSides(20)
        # 5F catheter radius
        polydataTube.SetRadius(0.7366)
        polydataTube.Update()
        # show on slicer for visualizing purposes
        modelNode = slicer.vtkMRMLModelNode()
        slicer.mrmlScene.AddNode(modelNode)
        modelNode.SetAndObservePolyData(polydataTube.GetOutput())
        # modelNode.CreateDefaultDisplayNodes()
        modelNodes.append(modelNode)

    #Create segmentation node
    segmentationNode = slicer.mrmlScene.AddNewNodeByClass('vtkMRMLSegmentationNode')
    # Convert all model nodes to segments
    for modelNode in modelNodes:
        modelSegment = slicer.vtkSlicerSegmentationsModuleLogic().CreateSegmentFromModelNode(modelNode)
        segmentationNode.GetSegmentation().AddSegment(modelSegment)

    # Display segmentation node 
    slicer.mrmlScene.AddNode(segmentationNode)
    segmentationNode.CreateDefaultDisplayNodes()
    
    # Create LabelMapVolumeNode for all segments
    labelmapVolumeNode = slicer.mrmlScene.AddNewNodeByClass('vtkMRMLLabelMapVolumeNode')
    # Export multiple segments to label map volume node
    slicer.modules.segmentations.logic().ExportVisibleSegmentsToLabelmapNode(segmentationNode, labelmapVolumeNode, ultrasoundNode)
    
    # Export Segmentation to numpy array
    output_file = 'downloads/numpy_data/Patient Segmentations/brachy_patient' + str(patient_num).zfill(2)
    segmentationArray = arrayFromVolume(labelmapVolumeNode)
    numpy.save(output_file, segmentationArray)

    # Export ultrasound volume node to numpy array
    ultrasound_file = 'downloads/numpy_data/Ultrasound Volumes/ultrasound' + str(patient_num).zfill(2)
    ultrasoundArray = arrayFromVolume(ultrasoundNode)
    numpy.save(ultrasound_file, ultrasoundArray)
# Out:
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150147_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150037_TempDICOMDatabase
# downloads/Brachy patients/PYPB01/DICOM/I1 != downloads/Brachy patients/PYPB01/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150204_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150147_TempDICOMDatabase
# downloads/Brachy patients/PYPB02/DICOM/I1 != downloads/Brachy patients/PYPB02/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150231_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150204_TempDICOMDatabase
# downloads/Brachy patients/PYPB03/DICOM/I112 != downloads/Brachy patients/PYPB03/DICOM/I0
# downloads/Brachy patients/PYPB03/DICOM/I112 != downloads/Brachy patients/PYPB03/DICOM/I1
# downloads/Brachy patients/PYPB03/DICOM/I112 != downloads/Brachy patients/PYPB03/DICOM/I2
# downloads/Brachy patients/PYPB03/DICOM/I2 != downloads/Brachy patients/PYPB03/DICOM/I0
# downloads/Brachy patients/PYPB03/DICOM/I2 != downloads/Brachy patients/PYPB03/DICOM/I1
# Loading with imageIOName: GDCM
# Loading with imageIOName: GDCM
#   Saving structure 2: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 2 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 2: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 2 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 2: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 2 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 2: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 2 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150322_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150231_TempDICOMDatabase
# downloads/Brachy patients/PYPB04/DICOM/I1 != downloads/Brachy patients/PYPB04/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150348_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150322_TempDICOMDatabase
# downloads/Brachy patients/PYPB05/DICOM/I1 != downloads/Brachy patients/PYPB05/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150415_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150348_TempDICOMDatabase
# downloads/Brachy patients/PYPB06/DICOM/I1 != downloads/Brachy patients/PYPB06/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150440_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150415_TempDICOMDatabase
# downloads/Brachy patients/PYPB07/DICOM/I1 != downloads/Brachy patients/PYPB07/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150508_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150440_TempDICOMDatabase
# downloads/Brachy patients/PYPB08/DICOM/I1 != downloads/Brachy patients/PYPB08/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150536_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150508_TempDICOMDatabase
# downloads/Brachy patients/PYPB09/DICOM/I1 != downloads/Brachy patients/PYPB09/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150558_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150536_TempDICOMDatabase
# downloads/Brachy patients/PYPB10/DICOM/I1 != downloads/Brachy patients/PYPB10/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150629_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150558_TempDICOMDatabase
# downloads/Brachy patients/PYPB11/DICOM/I1 != downloads/Brachy patients/PYPB11/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150657_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150629_TempDICOMDatabase
# downloads/Brachy patients/PYPB12/DICOM/I1 != downloads/Brachy patients/PYPB12/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150727_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150657_TempDICOMDatabase
# downloads/Brachy patients/PYPB13/DICOM/I1 != downloads/Brachy patients/PYPB13/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150755_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150727_TempDICOMDatabase
# downloads/Brachy patients/PYPB14/DICOM/I1 != downloads/Brachy patients/PYPB14/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150823_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150755_TempDICOMDatabase
# downloads/Brachy patients/PYPB15/DICOM/I1 != downloads/Brachy patients/PYPB15/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150850_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150823_TempDICOMDatabase
# downloads/Brachy patients/PYPB16/DICOM/I1 != downloads/Brachy patients/PYPB16/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150918_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150850_TempDICOMDatabase
# downloads/Brachy patients/PYPB17/DICOM/I1 != downloads/Brachy patients/PYPB17/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150946_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150918_TempDICOMDatabase
# downloads/Brachy patients/PYPB18/DICOM/I1 != downloads/Brachy patients/PYPB18/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151014_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_150946_TempDICOMDatabase
# downloads/Brachy patients/PYPB19/DICOM/I1 != downloads/Brachy patients/PYPB19/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151039_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151014_TempDICOMDatabase
# downloads/Brachy patients/PYPB20/DICOM/I1 != downloads/Brachy patients/PYPB20/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151105_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151039_TempDICOMDatabase
# downloads/Brachy patients/PYPB21/DICOM/I1 != downloads/Brachy patients/PYPB21/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151132_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151105_TempDICOMDatabase
# downloads/Brachy patients/PYPB22/DICOM/I1 != downloads/Brachy patients/PYPB22/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151202_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151132_TempDICOMDatabase
# downloads/Brachy patients/PYPB23/DICOM/I1 != downloads/Brachy patients/PYPB23/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151231_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151202_TempDICOMDatabase
# downloads/Brachy patients/PYPB24/DICOM/I1 != downloads/Brachy patients/PYPB24/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151255_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151231_TempDICOMDatabase
# downloads/Brachy patients/PYPB25/DICOM/I1 != downloads/Brachy patients/PYPB25/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151326_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151255_TempDICOMDatabase
# downloads/Brachy patients/PYPB26/DICOM/I1 != downloads/Brachy patients/PYPB26/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151354_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151326_TempDICOMDatabase
# downloads/Brachy patients/PYPB27/DICOM/I1 != downloads/Brachy patients/PYPB27/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151417_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151354_TempDICOMDatabase
# downloads/Brachy patients/PYPB28/DICOM/I1 != downloads/Brachy patients/PYPB28/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151447_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151417_TempDICOMDatabase
# downloads/Brachy patients/PYPB29/DICOM/I1 != downloads/Brachy patients/PYPB29/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
# Switching to temporary DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151512_TempDICOMDatabase
# Original DICOM database: C:/Users/z.hu/AppData/Local/Temp/Slicer/20190625_151447_TempDICOMDatabase
# downloads/Brachy patients/PYPB30/DICOM/I1 != downloads/Brachy patients/PYPB30/DICOM/I0
# Loading with imageIOName: GDCM
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV1
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV1.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._CTV2
#     to file 1 RTSTRUCT OCP RTS v4.2.2._CTV2.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Urethra
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Urethra.nrrd
#   Saving structure 1: RTSTRUCT: OCP RTS v4.2.2._Rectum
#     to file 1 RTSTRUCT OCP RTS v4.2.2._Rectum.nrrd
