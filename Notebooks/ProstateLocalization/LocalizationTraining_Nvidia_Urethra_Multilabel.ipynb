# %%
import datetime
import numpy as np
import scipy.ndimage
import os

from random import sample

from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import backend as keras
from keras.preprocessing.image import ImageDataGenerator

import keras.utils
# Out:
# Using TensorFlow backend.

# %%
batch_size = 3
num_epochs = 100

max_rotation_angle = 2.5
max_shift = 0.1
max_zoom = 0.1

# %%
ultrasound_fullname = 'numpy_data/Stacked Arrays/multi_label/Training/stacked_image_array.npy'
segmentation_fullname = 'numpy_data/Stacked Arrays/multi_label/Training/stacked_segmentation_array.npy'
urethra_fullname = 'numpy_data/Stacked Arrays/multi_label/Training/stacked_urethra_array.npy'

ultrasound_data = np.load(ultrasound_fullname)
segmentation_data = np.load(segmentation_fullname)
urethra_data = np.load(urethra_fullname)

ultrasound_size = ultrasound_data.shape[1:4]

num_ultrasound = ultrasound_data.shape[0]
num_segmentation = segmentation_data.shape[0]
num_urethra = urethra_data.shape[0]

print("\nFound {} ultrasound images and {} segmentations".format(num_ultrasound, num_segmentation))
print("Ultrasound size: {}".format(ultrasound_size))
# Out:
# Found 24 ultrasound images and 24 segmentations
# Ultrasound size: (128, 128, 128)

# %%
test_ultrasound_fullname = 'numpy_data/Stacked Arrays/multi_label/Test/test_image_array.npy'
test_segmentation_fullname = 'numpy_data/Stacked Arrays/multi_label/Test/test_segmentation_array.npy'
test_urethra_fullname = 'numpy_data/Stacked Arrays/multi_label/Test/test_urethra_array.npy'

test_ultrasound_data = np.load(test_ultrasound_fullname)
test_segmentation_data = np.load(test_segmentation_fullname)
test_urethra_data = np.load(test_urethra_fullname)

test_ultrasound_size = test_ultrasound_data.shape[1:4]

test_num_ultrasound = test_ultrasound_data.shape[0]
test_num_segmentation = test_segmentation_data.shape[0]
test_num_urethra = test_urethra_data.shape[0]

print("\nFound {} ultrasound images and {} segmentations".format(test_num_ultrasound, test_num_segmentation))
print("Ultrasound size: {}".format(test_ultrasound_size))
# Out:
# Found 6 ultrasound images and 6 segmentations
# Ultrasound size: (128, 128, 128)

# %%
# Multi-slice view code extracted and adapted from:
# https://www.datacamp.com/community/tutorials/matplotlib-3d-volumetric-data

import matplotlib.pyplot as plt

def multi_slice_viewer(volume):
    remove_keymap_conflicts({'j', 'k'})
    fig, ax = plt.subplots()
    ax.volume = volume
    ax.index = volume.shape[0] // 2
    ax.imshow(volume[ax.index])
    fig.canvas.mpl_connect('key_press_event', process_key)

def process_key(event):
    fig = event.canvas.figure
    ax = fig.axes[0]
    if event.key == 'j':
        previous_slice(ax)
    elif event.key == 'k':
        next_slice(ax)
    fig.canvas.draw()

def previous_slice(ax):
    volume = ax.volume
    ax.index = (ax.index - 1) % volume.shape[0]  # wrap around using %
    ax.images[0].set_array(volume[ax.index])

def next_slice(ax):
    volume = ax.volume
    ax.index = (ax.index + 1) % volume.shape[0]
    ax.images[0].set_array(volume[ax.index])

def remove_keymap_conflicts(new_keys_set):
    for prop in plt.rcParams:
        if prop.startswith('keymap.'):
            keys = plt.rcParams[prop]
            remove_list = set(keys) & new_keys_set
            for key in remove_list:
                keys.remove(key)

# %%
# Write some data samples for check

num_export = 3

indices = [i for i in range(num_ultrasound)]
sample_indices = sample(indices, num_export)

print("Exporting ultrasound samples: {}".format(sample_indices))

for i in range(num_export):
    print("Printing image #{:02d}".format(i))
    # np.save("Samples/sample_ultrasound_{:02d}".format(i), ultrasound_data[sample_indices[i], :, :, :, 0])
    # np.save("Samples/sample_segmentation_{:02d}".format(i), segmentation_data[sample_indices[i], :, :, :, 0])

multi_slice_viewer(urethra_data[sample_indices[i], :, :, :])
# Out:
# Exporting ultrasound samples: [10, 5, 16]
# Printing image #00
# Printing image #01
# Printing image #02

# %%
# Batch Generator

class UltrasoundSegmentationBatchGenerator(keras.utils.Sequence):
    
    def __init__(self,
                 x_set,
                 y1_set,
                 y2_set,
                 batch_size,
                 image_dimensions,
                 shuffle=True,
                 n_channels=1,
                 n_classes=3):
        self.x = x_set
        self.y1 = y1_set
        self.y2 = y2_set
        self.batch_size = batch_size
        self.image_dimensions = image_dimensions
        print("Generator created for image size: {}".format(self.image_dimensions))
        self.shuffle = shuffle
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.number_of_images = self.x.shape[0]
        self.indices = np.arange(self.number_of_images)
        if self.shuffle == True:
            np.random.shuffle(self.indices)
            
    def __len__(self):
        return int(np.floor(self.number_of_images / self.batch_size))
    
    def on_epoch_end(self):
        self.indices = np.arange(self.number_of_images)
        if self.shuffle == True:
            np.random.shuffle(self.indices)
    
    def __getitem__(self, index):
        batch_indices = self.indices[index*self.batch_size : (index+1)*self.batch_size]
        x = np.empty((self.batch_size, *self.image_dimensions, self.n_channels))
        y = np.empty((self.batch_size, *self.image_dimensions, self.n_classes))
        
        #labels[..., 1] = np.clip(gal_seg, 0, 1)
        #labels[..., 2] = np.clip(star_seg, 0, 1)

        for i in range(self.batch_size):
            flip_flag = np.random.randint(2)
            if flip_flag == 1:
                x[i,:,:,:,:] = self.x[batch_indices[i],:,:,:,:]
                y[i,:,:,:,1]   = self.y1[batch_indices[i],:,:,:]
                y[i,:,:,:,2]   = self.y2[batch_indices[i],:,:,:]
            else:
                x[i,:,:,:,:] = self.x[batch_indices[i],:,:,:,:]
                y[i,:,:,:,1]   = self.y1[batch_indices[i],:,:,:]
                y[i,:,:,:,2]   = self.y2[batch_indices[i],:,:,:]
            
        # Rotations
        
        x_rot = np.copy(x)
        y_rot = np.copy(y)
        
        '''        
        for i in range(self.batch_size):
            angle_x = np.random.randint(-max_rotation_angle, max_rotation_angle)
            x_rot[i,:,:,:,:] = scipy.ndimage.interpolation.rotate(
                x[i,:,:,:,:], angle_x, (1,2), False, mode="constant", cval=0, order=0)
            y_rot[i,:,:,:] = scipy.ndimage.interpolation.rotate(
                y[i,:,:,:], angle_x, (1,2), False, mode="constant", cval=0, order=0)
        '''    
            #angle_y = np.random.randint(-max_rotation_angle, max_rotation_angle)
            #x_rot[i,:,:,:,:] = scipy.ndimage.interpolation.rotate(
                #x_rot[i,:,:,:,:], angle_x, (0,2), False, mode="constant", cval=0, order=0)
            #y_rot[i,:,:,:] = scipy.ndimage.interpolation.rotate(
                #y[i,:,:,:], angle_x, (0,2), False, mode="constant", cval=0, order=0)
        
        
        # angle_z = np.random.randint(-max_rotation_angle, max_rotation_angle)
        # x_rot = scipy.ndimage.interpolation.rotate(x, angle_z, (0,1), False, mode="constant", cval=0, order=0)
        # y_rot = scipy.ndimage.interpolation.rotate(y, angle_z, (0,1), False, mode="constant", cval=0, order=0)
        
        # shift
        
        shift = np.random.uniform(-max_shift, max_shift, size=5)
        shift[0] = 0.0
        shift[4] = 0.0
        # x_shift = scipy.ndimage.interpolation.shift(x_rot, shift)
        # y_shift = scipy.ndimage.interpolation.shift(y_rot, shift[:4])
        
        # make sure values are between 0 and 1
        
        # x_aug = np.clip(x_shift, 0.0, 1.0)
        # y_aug = np.clip(y_shift, 0.0, 1.0)
        
        x_aug = np.clip(x_rot, 0.0, 1.0)
        y_aug = np.clip(y_rot, 0.0, 1.0)
        
        # convert segmentation to one-hot encoding
        
        # y_onehot = keras.utils.to_categorical(y_aug, self.n_classes)

        return x_aug, y_aug

# %%
# Test input generator

training_generator = UltrasoundSegmentationBatchGenerator(
    ultrasound_data,
    segmentation_data,
    urethra_data,
    batch_size,
    image_dimensions=(ultrasound_size))

bx, by = training_generator.__getitem__(0)

print("x shape: {} --- min: {} --- max: {}".format(bx.shape, bx.min(), bx.max()))
print("y shape: {} --- min: {} --- max: {}".format(by.shape, by.min(), by.max()))
# Out:
# Generator created for image size: (128, 128, 128)
# x shape: (3, 128, 128, 128, 1) --- min: 0.0 --- max: 0.9881422924901185
# y shape: (3, 128, 128, 128, 3) --- min: 0.0 --- max: 1.0

# %%
for i in range(batch_size):
    print("Printing image: bx_{:02d}".format(i))
    # np.save("Samples/bx_{:02d}".format(i), bx[i, :, :, :, 0])
    # np.save("Samples/by_{:02d}".format(i), by[i, :, :, :, 1])

multi_slice_viewer(by[i, :, :, :, 2])
# Out:
# Printing image: bx_00
# Printing image: bx_01
# Printing image: bx_02

# %%
def dilateStack(segmentation_data, iterations):
    return np.array([scipy.ndimage.binary_dilation(y, iterations=iterations) for y in segmentation_data])

width = 3
segmentation_dilated = dilateStack(segmentation_data[:, :, :, :], width)

# %%
num_classes = 3
filter_multiplier = 6

def nvidia_unet(input_size=128, num_classes=num_classes):
    input_ = Input((input_size, input_size, input_size, 1))
    skips = []
    output = input_
    c = num_classes
    
    num_layers = int(np.floor(np.log2(input_size)))
    down_conv_kernel_sizes = np.zeros([num_layers], dtype=int)
    down_filter_numbers = np.zeros([num_layers], dtype=int)
    up_conv_kernel_sizes = np.zeros([num_layers], dtype=int)
    up_filter_numbers = np.zeros([num_layers], dtype=int)
    
    for layer_index in range(num_layers):
        down_conv_kernel_sizes[layer_index] = int(3)
        down_filter_numbers[layer_index] = int( (layer_index + 1) * filter_multiplier + num_classes )
        up_conv_kernel_sizes[layer_index] = int(4)
        up_filter_numbers[layer_index] = int( (num_layers - layer_index - 1) * filter_multiplier + num_classes )
    
    print("Number of layers:       {}".format(num_layers))
    print("Filters in layers down: {}".format(down_filter_numbers))
    print("Filters in layers up:   {}".format(up_filter_numbers))
    
    for shape, filters in zip(down_conv_kernel_sizes, down_filter_numbers):
        skips.append(output)
        output= Conv3D(filters, (shape, shape, shape), strides=2, padding="same", activation="relu")(output)
        
    for shape, filters in zip(up_conv_kernel_sizes, up_filter_numbers):
        output = keras.layers.UpSampling3D()(output)
        skip_output = skips.pop()
        output = concatenate([output, skip_output], axis=4)

        if filters != num_classes:
            output = Conv3D(filters, (shape, shape, shape), activation="relu", padding="same")(output)
            output = BatchNormalization(momentum=.9)(output)
        else:
            # try sigmoid as the activation function
            output = Conv3D(filters, (shape, shape, shape), activation="softmax", padding="same")(output)
    
    assert len(skips) == 0
    return Model([input_], [output])

model = nvidia_unet(ultrasound_size[0], num_classes)

# model.summary()
# Out:
# Number of layers:       7
# Filters in layers down: [ 9 15 21 27 33 39 45]
# Filters in layers up:   [39 33 27 21 15  9  3]
# WARNING:tensorflow:From C:\Users\z.hu\AppData\Local\Continuum\anaconda3\envs\deepSeg\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
print("Model built with {} parameters".format(model.count_params()))
# Out:
# Model built with 715029 parameters

# %%
max_learning_rate = 0.05
min_learning_rate = 0.00001

learning_rate_decay = (max_learning_rate - min_learning_rate) / num_epochs

# loss = "categorical_crossentropy"
# metrics = "categorical_accuracy"
model.compile(optimizer=keras.optimizers.adam(lr=max_learning_rate, decay=learning_rate_decay),
               loss= "binary_crossentropy",
               metrics=["accuracy"])

print("Learning rate decay = {}".format(learning_rate_decay))
# Out:
# Learning rate decay = 0.0004999

# %%
training_generator = UltrasoundSegmentationBatchGenerator(
    ultrasound_data,
    segmentation_data,
    urethra_data,
    batch_size,
    image_dimensions=(ultrasound_size))
test_generator = UltrasoundSegmentationBatchGenerator(
    test_ultrasound_data,
    test_segmentation_data,
    test_urethra_data,
    batch_size,
    image_dimensions=(ultrasound_size))

training_time_start = datetime.datetime.now()

training_log = model.fit_generator(training_generator,
                                   validation_data=test_generator,
                                   epochs=num_epochs,
                                   verbose=1)
# Out:
# Generator created for image size: (128, 128, 128)
# Generator created for image size: (128, 128, 128)
# WARNING:tensorflow:From C:\Users\z.hu\AppData\Local\Continuum\anaconda3\envs\deepSeg\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From C:\Users\z.hu\AppData\Local\Continuum\anaconda3\envs\deepSeg\lib\site-packages\tensorflow\python\ops\math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Epoch 1/100
# 8/8 [==============================] - 17s 2s/step - loss: 2.2317 - acc: 0.6847 - val_loss: 4.6272 - val_acc: 0.6662
# Epoch 2/100
# 8/8 [==============================] - 7s 934ms/step - loss: 0.9562 - acc: 0.6808 - val_loss: 1.5519 - val_acc: 0.6670
# Epoch 3/100
# 8/8 [==============================] - 7s 921ms/step - loss: 0.7012 - acc: 0.6815 - val_loss: 2.2192 - val_acc: 0.6688
# Epoch 4/100
# 8/8 [==============================] - 8s 960ms/step - loss: 0.5976 - acc: 0.6695 - val_loss: 0.5074 - val_acc: 0.6725
# Epoch 5/100
# 8/8 [==============================] - 8s 946ms/step - loss: 0.5279 - acc: 0.6983 - val_loss: 0.5982 - val_acc: 0.6785
# Epoch 6/100
# 8/8 [==============================] - 8s 948ms/step - loss: 0.5234 - acc: 0.7034 - val_loss: 0.5598 - val_acc: 0.6970
# Epoch 7/100
# 8/8 [==============================] - 8s 950ms/step - loss: 0.4969 - acc: 0.6984 - val_loss: 0.4468 - val_acc: 0.7866
# Epoch 8/100
# 8/8 [==============================] - 7s 931ms/step - loss: 0.4640 - acc: 0.7452 - val_loss: 0.4458 - val_acc: 0.8595
# Epoch 9/100
# 8/8 [==============================] - 8s 942ms/step - loss: 0.4551 - acc: 0.7880 - val_loss: 0.4732 - val_acc: 0.7235
# Epoch 10/100
# 8/8 [==============================] - 8s 938ms/step - loss: 0.4538 - acc: 0.8084 - val_loss: 0.4374 - val_acc: 0.8863
# Epoch 11/100
# 8/8 [==============================] - 8s 955ms/step - loss: 0.4368 - acc: 0.8881 - val_loss: 0.4262 - val_acc: 0.9943
# Epoch 12/100
# 8/8 [==============================] - 8s 945ms/step - loss: 0.4291 - acc: 0.9193 - val_loss: 0.4223 - val_acc: 0.9678
# Epoch 13/100
# 8/8 [==============================] - 7s 911ms/step - loss: 0.4277 - acc: 0.9412 - val_loss: 0.4426 - val_acc: 0.9420
# Epoch 14/100
# 8/8 [==============================] - 8s 971ms/step - loss: 0.4298 - acc: 0.9251 - val_loss: 0.4243 - val_acc: 0.8612
# Epoch 15/100
# 8/8 [==============================] - 8s 945ms/step - loss: 0.4210 - acc: 0.9693 - val_loss: 0.4406 - val_acc: 0.7479
# Epoch 16/100
# 8/8 [==============================] - 7s 933ms/step - loss: 0.4214 - acc: 0.9482 - val_loss: 0.4108 - val_acc: 0.9952
# Epoch 17/100
# 8/8 [==============================] - 8s 946ms/step - loss: 0.4161 - acc: 0.9809 - val_loss: 0.4252 - val_acc: 0.9950
# Epoch 18/100
# 8/8 [==============================] - 7s 928ms/step - loss: 0.4156 - acc: 0.9932 - val_loss: 0.4141 - val_acc: 0.9952
# Epoch 19/100
# 8/8 [==============================] - 8s 960ms/step - loss: 0.4117 - acc: 0.9924 - val_loss: 0.4109 - val_acc: 0.9952
# Epoch 20/100
# 8/8 [==============================] - 7s 936ms/step - loss: 0.4100 - acc: 0.9956 - val_loss: 0.4091 - val_acc: 0.9952
# Epoch 21/100
# 8/8 [==============================] - 8s 946ms/step - loss: 0.4092 - acc: 0.9956 - val_loss: 0.4094 - val_acc: 0.9952
# Epoch 22/100
# 8/8 [==============================] - 7s 936ms/step - loss: 0.4090 - acc: 0.9956 - val_loss: 0.4088 - val_acc: 0.9952
# Epoch 23/100
# 8/8 [==============================] - 8s 958ms/step - loss: 0.4087 - acc: 0.9956 - val_loss: 0.4089 - val_acc: 0.9952
# Epoch 24/100
# 8/8 [==============================] - 8s 945ms/step - loss: 0.4087 - acc: 0.9956 - val_loss: 0.4087 - val_acc: 0.9952
# Epoch 25/100
# 8/8 [==============================] - 8s 941ms/step - loss: 0.4085 - acc: 0.9956 - val_loss: 0.4088 - val_acc: 0.9952
# Epoch 26/100
# 8/8 [==============================] - 8s 960ms/step - loss: 0.4086 - acc: 0.9956 - val_loss: 0.4088 - val_acc: 0.9952
# Epoch 27/100
# 8/8 [==============================] - 8s 938ms/step - loss: 0.4086 - acc: 0.9956 - val_loss: 0.4093 - val_acc: 0.9952
# Epoch 28/100
# 8/8 [==============================] - 8s 938ms/step - loss: 0.4088 - acc: 0.9956 - val_loss: 0.4096 - val_acc: 0.9952
# Epoch 29/100
# 8/8 [==============================] - 8s 945ms/step - loss: 0.4091 - acc: 0.9956 - val_loss: 0.4087 - val_acc: 0.9952
# Epoch 30/100
# 8/8 [==============================] - 7s 921ms/step - loss: 0.4088 - acc: 0.9956 - val_loss: 0.4087 - val_acc: 0.9952
# Epoch 31/100
# 8/8 [==============================] - 7s 929ms/step - loss: 0.4087 - acc: 0.9956 - val_loss: 0.4087 - val_acc: 0.9952
# Epoch 32/100
# 8/8 [==============================] - 8s 981ms/step - loss: 0.4086 - acc: 0.9956 - val_loss: 0.4088 - val_acc: 0.9952
# Epoch 33/100
# 8/8 [==============================] - 8s 949ms/step - loss: 0.4086 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 34/100
# 8/8 [==============================] - 8s 946ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 35/100
# 8/8 [==============================] - 7s 934ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 36/100
# 8/8 [==============================] - 7s 920ms/step - loss: 0.4085 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 37/100
# 8/8 [==============================] - 8s 959ms/step - loss: 0.4086 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 38/100
# 8/8 [==============================] - 7s 937ms/step - loss: 0.4085 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 39/100
# 8/8 [==============================] - 7s 932ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 40/100
# 8/8 [==============================] - 7s 936ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 41/100
# 8/8 [==============================] - 8s 941ms/step - loss: 0.4085 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 42/100
# 8/8 [==============================] - 7s 933ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 43/100
# 8/8 [==============================] - 8s 959ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 44/100
# 8/8 [==============================] - 7s 928ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4088 - val_acc: 0.9952
# Epoch 45/100
# 8/8 [==============================] - 8s 947ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4090 - val_acc: 0.9952
# Epoch 46/100
# 8/8 [==============================] - 8s 938ms/step - loss: 0.4087 - acc: 0.9956 - val_loss: 0.4090 - val_acc: 0.9952
# Epoch 47/100
# 8/8 [==============================] - 8s 948ms/step - loss: 0.4089 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 48/100
# 8/8 [==============================] - 8s 938ms/step - loss: 0.4088 - acc: 0.9956 - val_loss: 0.4097 - val_acc: 0.9952
# Epoch 49/100
# 8/8 [==============================] - 7s 935ms/step - loss: 0.4087 - acc: 0.9956 - val_loss: 0.4093 - val_acc: 0.9952
# Epoch 50/100
# 8/8 [==============================] - 7s 926ms/step - loss: 0.4087 - acc: 0.9956 - val_loss: 0.4087 - val_acc: 0.9952
# Epoch 51/100
# 8/8 [==============================] - 8s 955ms/step - loss: 0.4085 - acc: 0.9956 - val_loss: 0.4087 - val_acc: 0.9952
# Epoch 52/100
# 8/8 [==============================] - 8s 947ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 53/100
# 8/8 [==============================] - 8s 939ms/step - loss: 0.4085 - acc: 0.9956 - val_loss: 0.4089 - val_acc: 0.9952
# Epoch 54/100
# 8/8 [==============================] - 8s 948ms/step - loss: 0.4088 - acc: 0.9956 - val_loss: 0.4090 - val_acc: 0.9952
# Epoch 55/100
# 8/8 [==============================] - 8s 946ms/step - loss: 0.4086 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 56/100
# 8/8 [==============================] - 7s 937ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 57/100
# 8/8 [==============================] - 7s 934ms/step - loss: 0.4085 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 58/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 59/100
# 8/8 [==============================] - 8s 955ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 60/100
# 8/8 [==============================] - 8s 950ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 61/100
# 8/8 [==============================] - 8s 938ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 62/100
# 8/8 [==============================] - 8s 950ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 63/100
# 8/8 [==============================] - 8s 950ms/step - loss: 0.4083 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 64/100
# 8/8 [==============================] - 8s 941ms/step - loss: 0.4083 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 65/100
# 8/8 [==============================] - 8s 953ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 66/100
# 8/8 [==============================] - 7s 924ms/step - loss: 0.4085 - acc: 0.9956 - val_loss: 0.4089 - val_acc: 0.9952
# Epoch 67/100
# 8/8 [==============================] - 7s 937ms/step - loss: 0.4087 - acc: 0.9956 - val_loss: 0.4089 - val_acc: 0.9952
# Epoch 68/100
# 8/8 [==============================] - 8s 958ms/step - loss: 0.4088 - acc: 0.9956 - val_loss: 0.4088 - val_acc: 0.9952
# Epoch 69/100
# 8/8 [==============================] - 7s 920ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 70/100
# 8/8 [==============================] - 8s 961ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4089 - val_acc: 0.9952
# Epoch 71/100
# 8/8 [==============================] - 7s 936ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 72/100
# 8/8 [==============================] - 8s 953ms/step - loss: 0.4083 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 73/100
# 8/8 [==============================] - 7s 936ms/step - loss: 0.4083 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 74/100
# 8/8 [==============================] - 8s 950ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 75/100
# 8/8 [==============================] - 8s 939ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 76/100
# 8/8 [==============================] - 8s 940ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 77/100
# 8/8 [==============================] - 8s 940ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4088 - val_acc: 0.9952
# Epoch 78/100
# 8/8 [==============================] - 8s 942ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 79/100
# 8/8 [==============================] - 8s 944ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 80/100
# 8/8 [==============================] - 8s 947ms/step - loss: 0.4083 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 81/100
# 8/8 [==============================] - 7s 918ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4088 - val_acc: 0.9952
# Epoch 82/100
# 8/8 [==============================] - 8s 954ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 83/100
# 8/8 [==============================] - 7s 932ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 84/100
# 8/8 [==============================] - 8s 946ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 85/100
# 8/8 [==============================] - 8s 941ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 86/100
# 8/8 [==============================] - 7s 921ms/step - loss: 0.4083 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 87/100
# 8/8 [==============================] - 8s 961ms/step - loss: 0.4083 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 88/100
# 8/8 [==============================] - 7s 929ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 89/100
# 8/8 [==============================] - 7s 930ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4087 - val_acc: 0.9952
# Epoch 90/100
# 8/8 [==============================] - 8s 964ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 91/100
# 8/8 [==============================] - 8s 950ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 92/100
# 8/8 [==============================] - 8s 944ms/step - loss: 0.4083 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 93/100
# 8/8 [==============================] - 8s 945ms/step - loss: 0.4083 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 94/100
# 8/8 [==============================] - 8s 948ms/step - loss: 0.4083 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 95/100
# 8/8 [==============================] - 7s 902ms/step - loss: 0.4083 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 96/100
# 8/8 [==============================] - 8s 939ms/step - loss: 0.4083 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 97/100
# 8/8 [==============================] - 7s 922ms/step - loss: 0.4083 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 98/100
# 8/8 [==============================] - 7s 922ms/step - loss: 0.4083 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952
# Epoch 99/100
# 8/8 [==============================] - 8s 946ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4086 - val_acc: 0.9952
# Epoch 100/100
# 8/8 [==============================] - 7s 909ms/step - loss: 0.4084 - acc: 0.9956 - val_loss: 0.4085 - val_acc: 0.9952

# %%
training_time_stop = datetime.datetime.now()
print("Training started at: {}".format(training_time_start))
print("Training stopped at: {}".format(training_time_stop))
print("Total training time: {}".format(training_time_stop-training_time_start))
# Out:
# Training started at: 2019-08-06 14:56:04.238041
# Training stopped at: 2019-08-06 15:08:52.937775
# Total training time: 0:12:48.699734

# %%
import datetime

timestamp = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')

saved_models_folder = 'saved_models'
model_file_name = "model_" + timestamp + ".h5"
weights_file_path = os.path.join(saved_models_folder, model_file_name)

model.save(weights_file_path)
print("Unet Model saved to: {}".format(weights_file_path))
# Out:
# Unet Model saved to: saved_models\model_2019-08-06_15-08-52.h5

# %%
trained_model = load_model(weights_file_path)
print(weights_file_path)
# Out:
# saved_models\model_2019-08-06_15-08-52.h5

# %%
y_pred = trained_model.predict(test_ultrasound_data[0:1, :, :, :, :])

# %%
# %matplotlib notebook

# %%
# Display training loss and accuracy curves over epochs

import matplotlib.pyplot as plt

plt.figure(1)

plt.subplot(211)
plt.plot(training_log.history['loss'], 'bo--')
plt.plot(training_log.history['val_loss'], 'ro-')
plt.ylabel('Loss')
plt.xlabel('Epochs (n)')
plt.legend(['Training loss', 'Validation loss'])
plt.show()

plt.subplot(212)
plt.plot(training_log.history['acc'], 'bo--')
plt.plot(training_log.history['val_acc'], 'ro-')
plt.ylabel('Accuracy')
plt.xlabel('Epochs (n)')
plt.legend(['Training accuracy', 'Validation accuracy'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# ultrasound
ultrasound_img = test_ultrasound_data[0]
print(ultrasound_img.shape)
multi_slice_viewer(ultrasound_img[:, :, :, 0])
# Out:
# (128, 128, 128, 1)
# <img src="data:image/png;base64,..." width="640">

# %%
# Segmentation
segmentation_img = test_segmentation_data[0]
print(segmentation_img.shape)
multi_slice_viewer(segmentation_img[:, :, :])
# Out:
# (128, 128, 128)
# <img src="data:image/png;base64,..." width="640">

# %%
# Prediction
predicted_img = y_pred[0]
print(predicted_img.shape)
multi_slice_viewer(predicted_img[:, :, :, 1])
# Out:
# (128, 128, 128, 3)
# <img src="data:image/png;base64,..." width="640">

# %%
# Exporting volumes

export_index = 0
export_folder = 'saved_models/Slicer Export'

ultrasound_fullname = os.path.join(export_folder, "ultrasound_" + str(export_index))
segmentation_fullname = os.path.join(export_folder, "segmentation_" + str(export_index))
prediction_fullname = os.path.join(export_folder, "prediction_" + str(export_index))

np.save(ultrasound_fullname, ultrasound_img[:, :, :, 0])
np.save(segmentation_fullname, segmentation_img[:, :, :])
np.save(prediction_fullname, predicted_img[:, :, :, 1])

print("Sample ultrasound saved to:   {}".format(ultrasound_fullname))
print("Sample segmentation saved to: {}".format(segmentation_fullname))
print("Sample prediction saved to    {}".format(prediction_fullname))
# Out:
# Sample ultrasound saved to:   saved_models/Slicer Export\ultrasound_0
# Sample segmentation saved to: saved_models/Slicer Export\segmentation_0
# Sample prediction saved to    saved_models/Slicer Export\prediction_0
