# %%
import math
import matplotlib.pyplot as plt
import numpy as np

# %%
# Cross entropy

x = np.arange(0.0001, 1.0, 0.01)

# %%
y = - np.log(1-x)

plt.plot(x,y)

# %%
# MSE

y = x * x

plt.plot(x,y)
